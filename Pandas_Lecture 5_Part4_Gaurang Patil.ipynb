# %%
#Load pandas library
import pandas as pd
import warnings 
  
# Settings the warnings to be ignored 
warnings.filterwarnings('ignore') 

diamonds_df = pd.read_csv('diamonds.csv')

diamonds_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# --- Added the code here ---
diamonds_df.shape
# ---------------------------
# Out:
# (53940, 14)

# %%
# --- Added the code here ---
diamonds_df.describe()
# ---------------------------
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   5112.639638      5.731157
# std        0.474011      1.432621      2.234491   5186.271660      1.121761
# min        0.200000     43.000000     43.000000    423.800000      0.000000
# 25%        0.400000     61.000000     56.000000   1235.000000      4.710000
# 50%        0.700000     61.800000     57.000000   3121.300000      5.700000
# 75%        1.040000     62.500000     59.000000   6921.525000      6.540000
# max        5.010000     79.000000     95.000000  24469.900000     10.740000
#
#                   y             z  price_per_carat  price_per_carat_is_high  \
# count  53940.000000  53940.000000     53940.000000             53940.000000
# mean       5.734526      3.538734      4008.394796                 0.499481
# std        1.142135      0.705699      2012.665747                 0.500004
# min        0.000000      0.000000      1051.162791                 0.000000
# 25%        4.720000      2.910000      2477.944444                 0.000000
# 50%        5.710000      3.530000      3495.198031                 0.000000
# 75%        6.540000      4.040000      4949.599702                 1.000000
# max       58.900000     31.800000     17828.846154                 1.000000
#
#        rounded_price
# count   53940.000000
# mean     5113.086244
# std      5186.272888
# min       424.000000
# 25%      1235.000000
# 50%      3122.000000
# 75%      6922.250000
# max     24470.000000

# %%
# --- Added the code here ---
diamonds_df.describe(include = object)
# ---------------------------
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %%
# --- Added the code here ---
diamonds_df.info()
# ---------------------------
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
# --- Added the code here ---
diamonds_df['price_per_carat'] = diamonds_df['price']/diamonds_df['carat']
# ---------------------------

# %%
diamonds_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        price_per_carat
# 0          1417.391304
# 1          1552.380952
# 2          1421.739130
# 3          1151.724138
# 4          1080.645161
# ...                ...
# 53935      3829.166667
# 53936      3829.166667
# 53937      3938.571429
# 53938      3205.813953
# 53939      3676.000000
#
# [53940 rows x 11 columns]

# %%
import numpy as np

# --- Added the code here ---
diamonds_df['price_per_carat_is_high'] = np.where(diamonds_df['price_per_carat']>3500, 1, 0)
# ---------------------------

diamonds_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        price_per_carat  price_per_carat_is_high
# 0          1417.391304                        0
# 1          1552.380952                        0
# 2          1421.739130                        0
# 3          1151.724138                        0
# 4          1080.645161                        0
# ...                ...                      ...
# 53935      3829.166667                        1
# 53936      3829.166667                        1
# 53937      3938.571429                        1
# 53938      3205.813953                        0
# 53939      3676.000000                        1
#
# [53940 rows x 12 columns]

# %%
# --- Added the code here ---
diamonds_df['price'] = diamonds_df['price']*1.3 
# ---------------------------

diamonds_df
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0   423.8  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   423.8  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   425.1  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   434.2  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   435.5  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  3584.1  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  3584.1  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  3584.1  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0  3584.1  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  3584.1  5.83  5.87  3.64
#
#        price_per_carat  price_per_carat_is_high
# 0          1417.391304                        0
# 1          1552.380952                        0
# 2          1421.739130                        0
# 3          1151.724138                        0
# 4          1080.645161                        0
# ...                ...                      ...
# 53935      3829.166667                        1
# 53936      3829.166667                        1
# 53937      3938.571429                        1
# 53938      3205.813953                        0
# 53939      3676.000000                        1
#
# [53940 rows x 12 columns]

# %%
import math

# --- Added the code here ---
diamonds_df['rounded_price'] = diamonds_df['price'].apply(math.ceil)
# ---------------------------

diamonds_df
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0   423.8  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   423.8  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   425.1  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   434.2  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   435.5  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  3584.1  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  3584.1  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  3584.1  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0  3584.1  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  3584.1  5.83  5.87  3.64
#
#        price_per_carat  price_per_carat_is_high desired  rounded_price
# 0          1417.391304                        0      no            424
# 1          1552.380952                        0      no            424
# 2          1421.739130                        0      no            426
# 3          1151.724138                        0      no            435
# 4          1080.645161                        0      no            436
# ...                ...                      ...     ...            ...
# 53935      3829.166667                        1     yes           3585
# 53936      3829.166667                        1      no           3585
# 53937      3938.571429                        1      no           3585
# 53938      3205.813953                        0      no           3585
# 53939      3676.000000                        1     yes           3585
#
# [53940 rows x 14 columns]

# %%
def is_desired(x):
    bool_var = 'yes' if (x['cut']=='Ideal' and x['color']=='D') else 'no'
    return bool_var

# %%
diamonds_df['desired'] = diamonds_df.apply(is_desired, axis=1)

diamonds_df
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0   423.8  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   423.8  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   425.1  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   434.2  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   435.5  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  3584.1  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  3584.1  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  3584.1  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0  3584.1  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  3584.1  5.83  5.87  3.64
#
#        price_per_carat  price_per_carat_is_high desired
# 0          1417.391304                        0      no
# 1          1552.380952                        0      no
# 2          1421.739130                        0      no
# 3          1151.724138                        0      no
# 4          1080.645161                        0      no
# ...                ...                      ...     ...
# 53935      3829.166667                        1     yes
# 53936      3829.166667                        1      no
# 53937      3938.571429                        1      no
# 53938      3205.813953                        0      no
# 53939      3676.000000                        1     yes
#
# [53940 rows x 13 columns]

# %%
diamonds_df.to_csv('diamonds_modified.csv')

# %%
import matplotlib.pyplot as plt

diamonds_df.carat.plot.hist(orientation = 'vertical')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### Revised Date: July 18, 2024
